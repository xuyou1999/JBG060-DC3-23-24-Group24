# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import timedelta

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix

# %%
def classification_evaluation(y_test, y_pred, avg="weighted"):

    precision = precision_score(y_test, y_pred, average=avg, zero_division=0)
    recall = recall_score(y_test, y_pred, average=avg, zero_division=0)
    F1_score = f1_score(y_test, y_pred, average=avg, zero_division=0)
    accuracy = accuracy_score(y_test, y_pred)
    
    print(f'Accuracy: {round(accuracy,3)}')
    print(f'Precision: {round(precision,3)}')
    print(f'Recall: {round(recall,3)}')
    print(f'f1-score: {round(F1_score,3)}')
    print(f'Confusion matrix: \n {confusion_matrix(y_test, y_pred)}')

# %%
# df_summaries = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"])
# df_summaries

# %%
# df_articles = pd.read_csv("data/all_africa_southsudan.csv")
# df_articles

# %%
# print(df_articles.date.unique().shape)

# %%
df_tabular = pd.read_csv("data/food_crises_interpol_news.csv")

# %%
df_tabular = df_tabular.set_index('year_month')
df_tabular.index = pd.to_datetime(df_tabular.index)
df_tabular['timestamp']=df_tabular.index

# %%
df_tabular[['district', 'hunger_positive', 'hunger_negative',
       'refugees_positive', 'refugees_negative', 'humanitarian_positive',
       'humanitarian_negative', 'conflict_positive', 'conflict_negative',
       'vulnerability_positive', 'vulnerability_negative']]
# Out:
#                 district  hunger_positive  hunger_negative  refugees_positive  \
# year_month
# 2009-11-01     Abiemnhom              0.0              0.0                0.0
# 2009-11-01         Akobo              0.0              0.0                0.0
# 2009-11-01  Aweil Center              0.0              0.0                0.0
# 2009-11-01    Aweil East              0.0              0.0                0.0
# 2009-11-01   Aweil North              0.0              0.0                0.0
# ...                  ...              ...              ...                ...
# 2020-01-01          Wulu              0.0              0.0                0.0
# 2020-01-01        Yambio              0.0              0.0                0.0
# 2020-01-01           Yei              0.0              0.0                0.0
# 2020-01-01    Yirol East              0.0              0.0                0.0
# 2020-01-01    Yirol West              0.0              0.0                0.0
#
#             refugees_negative  humanitarian_positive  humanitarian_negative  \
# year_month
# 2009-11-01                0.0                    0.0                    0.0
# 2009-11-01                0.0                    0.0                    0.0
# 2009-11-01                0.0                    0.0                    0.0
# 2009-11-01                0.0                    0.0                    0.0
# 2009-11-01                0.0                    0.0                    0.0
# ...                       ...                    ...                    ...
# 2020-01-01                0.0                    0.0                    0.0
# 2020-01-01                0.0                    0.0                    0.0
# 2020-01-01                0.0                    0.0                    0.0
# 2020-01-01                0.0                    0.0                    0.0
# 2020-01-01                0.0                    0.0                    0.0
#
#             conflict_positive  conflict_negative  vulnerability_positive  \
# year_month
# 2009-11-01                0.0                0.0                     0.0
# 2009-11-01                0.0                0.0                     0.0
# 2009-11-01                0.0                0.0                     0.0
# 2009-11-01                0.0                0.0                     0.0
# 2009-11-01                0.0                0.0                     0.0
# ...                       ...                ...                     ...
# 2020-01-01                0.0                0.0                     0.0
# 2020-01-01                0.0                0.0                     0.0
# 2020-01-01                0.0                0.0                     0.0
# 2020-01-01                0.0                0.0                     0.0
# 2020-01-01                0.0                0.0                     0.0
#
#             vulnerability_negative
# year_month
# 2009-11-01                     0.0
# 2009-11-01                     0.0
# 2009-11-01                     0.0
# 2009-11-01                     0.0
# 2009-11-01                     0.0
# ...                            ...
# 2020-01-01                     0.0
# 2020-01-01                     0.0
# 2020-01-01                     0.0
# 2020-01-01                     0.0
# 2020-01-01                     0.0
#
# [9471 rows x 11 columns]

# %%
df_tabular.columns
# Out:
# Index(['date', 'county', 'Unnamed: 0', 'district', 'region', 'ipc',
#        'ndvi_mean', 'ndvi_anom', 'rain_mean', 'rain_anom', 'et_mean',
#        'et_anom', 'count_violence', 'sum_fatalities', 'food_price_idx', 'area',
#        'cropland_pct', 'pop', 'ruggedness_mean', 'pasture_pct', 'prev_ipc',
#        '2prev_ipc', 'next_ipc', 'hunger_positive', 'hunger_negative',
#        'refugees_positive', 'refugees_negative', 'humanitarian_positive',
#        'humanitarian_negative', 'conflict_positive', 'conflict_negative',
#        'vulnerability_positive', 'vulnerability_negative', 'timestamp'],
#       dtype='object')

# %%
df_model = df_tabular[['district', 'ipc', 'ndvi_mean', 'ndvi_anom', 'rain_mean',
       'rain_anom', 'et_mean', 'et_anom', 'count_violence', 'sum_fatalities',
       'food_price_idx', 'area', 'cropland_pct', 'pop', 'ruggedness_mean',
       'pasture_pct', 'hunger_positive', 'hunger_negative',
       'refugees_positive', 'refugees_negative', 'humanitarian_positive',
       'humanitarian_negative', 'conflict_positive', 'conflict_negative',
       'vulnerability_positive', 'vulnerability_negative', 'timestamp']]

# %%
train = df_model.loc[df_model.index < '2019-03-01']
# val = df_model.loc[(df_model.index >= '2019-03-01') & (df_model.index < '2019-09-01')]
test = df_model.loc[df_model.index >= '2019-03-01']

# %%
test.timestamp
# Out:
# year_month
# 2019-03-01   2019-03-01
# 2019-03-01   2019-03-01
# 2019-03-01   2019-03-01
# 2019-03-01   2019-03-01
# 2019-03-01   2019-03-01
#                 ...
# 2020-01-01   2020-01-01
# 2020-01-01   2020-01-01
# 2020-01-01   2020-01-01
# 2020-01-01   2020-01-01
# 2020-01-01   2020-01-01
# Name: timestamp, Length: 847, dtype: datetime64[ns]

# %%
train.index
# Out:
# DatetimeIndex(['2009-11-01', '2009-11-01', '2009-11-01', '2009-11-01',
#                '2009-11-01', '2009-11-01', '2009-11-01', '2009-11-01',
#                '2009-11-01', '2009-11-01',
#                ...
#                '2019-02-01', '2019-02-01', '2019-02-01', '2019-02-01',
#                '2019-02-01', '2019-02-01', '2019-02-01', '2019-02-01',
#                '2019-02-01', '2019-02-01'],
#               dtype='datetime64[ns]', name='year_month', length=8624, freq=None)

# %%
test.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-01', '2019-03-01', '2019-03-01',
#                '2019-03-01', '2019-03-01', '2019-03-01', '2019-03-01',
#                '2019-03-01', '2019-03-01',
#                ...
#                '2020-01-01', '2020-01-01', '2020-01-01', '2020-01-01',
#                '2020-01-01', '2020-01-01', '2020-01-01', '2020-01-01',
#                '2020-01-01', '2020-01-01'],
#               dtype='datetime64[ns]', name='year_month', length=847, freq=None)

# %% [markdown]
# # DeepAR

# %%
# pip install gluonts

# %%
from gluonts.dataset.pandas import PandasDataset

train_ds = PandasDataset.from_long_dataframe(train, target='ipc', item_id='district', 
                                       timestamp='timestamp', freq='M')

# %%
# pip install torch

# %%
# pip install pytorch_lightning

# %%
train_ds
# Out:
# PandasDataset<size=77, freq=M, num_feat_dynamic_real=0, num_past_feat_dynamic_real=0, num_feat_static_real=0, num_feat_static_cat=0, static_cardinalities=[]>

# %%
from gluonts.torch.model.deepar import DeepAREstimator

estimator = DeepAREstimator(freq='M', prediction_length=6, num_layers=4, lr=0.002, context_length=12,
                            trainer_kwargs={'max_epochs':8})

predictor = estimator.train(train_ds, num_workers=4)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\Goshko\anaconda3\envs\dc3\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:71: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
#
#   | Name  | Type        | Params | In sizes | Out sizes
# ---------------------------------------------------------------
# 0 | model | DeepARModel | 49.6 K | ?        | [1, 100, 6]
# ---------------------------------------------------------------
# 49.6 K    Trainable params
# 0         Non-trainable params
# 49.6 K    Total params
# 0.198     Total estimated model params size (MB)
# Epoch 0: : 50it [00:03, 15.77it/s, v_num=71, train_loss=1.140]
# Epoch 0, global step 50: 'train_loss' reached 1.13628 (best 1.13628), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1: : 50it [00:02, 19.21it/s, v_num=71, train_loss=0.621]
# Epoch 1, global step 100: 'train_loss' reached 0.62134 (best 0.62134), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2: : 50it [00:03, 14.76it/s, v_num=71, train_loss=0.585]
# Epoch 2, global step 150: 'train_loss' reached 0.58518 (best 0.58518), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3: : 50it [00:03, 15.52it/s, v_num=71, train_loss=0.593]
# Epoch 3, global step 200: 'train_loss' was not in top 1
# Epoch 4: : 50it [00:03, 14.67it/s, v_num=71, train_loss=0.534]
# Epoch 4, global step 250: 'train_loss' reached 0.53416 (best 0.53416), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5: : 50it [00:03, 14.78it/s, v_num=71, train_loss=0.490]
# Epoch 5, global step 300: 'train_loss' reached 0.48993 (best 0.48993), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=5-step=300.ckpt' as top 1
# Epoch 6: : 50it [00:03, 14.96it/s, v_num=71, train_loss=0.345]
# Epoch 6, global step 350: 'train_loss' reached 0.34487 (best 0.34487), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=6-step=350.ckpt' as top 1
# Epoch 7: : 50it [00:02, 17.94it/s, v_num=71, train_loss=0.227]
# Epoch 7, global step 400: 'train_loss' reached 0.22698 (best 0.22698), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_71\\checkpoints\\epoch=7-step=400.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=8` reached.
# Epoch 7: : 50it [00:02, 17.75it/s, v_num=71, train_loss=0.227]

# %%
pred = list(predictor.predict(train_ds))
all_preds = list()

for district in pred:
    district_name = district.item_id
    p = district.samples.mean(axis=0)
    # make 80% confidence interval
    p10 = np.percentile(district.samples, 10, axis=0)
    p90 = np.percentile(district.samples, 90, axis=0)
    dates = pd.date_range(start=district.start_date.to_timestamp(), periods=len(p), freq='M')
    dates2 = []
    for month in dates:
        day_num = month.strftime("%d")
        month_reset = month - timedelta(days=int(day_num) - 1)
        dates2.append(month_reset)
    district_pred = pd.DataFrame({'timestamp': dates2, 'district': district_name, 'pred': p, 'p10': p10, 'p90': p90})
    all_preds += [district_pred]

all_preds = pd.concat(all_preds, ignore_index=True)

# all_preds['date'] = all_preds.timestamp
# all_preds = all_preds.set_index('date')
# all_preds.index = pd.to_datetime(all_preds.index)
# all_preds.timestamp=all_preds.index

all_preds = all_preds.merge(test, on=['timestamp', 'district'], how='left')
all_preds['pred'] = all_preds['pred'].apply(round)

all_preds[['timestamp', 'district', 'ipc', 'pred', 'p10', 'p90']]
# Out:
#      timestamp    district  ipc  pred       p10       p90
# 0   2019-03-01   Abiemnhom  3.0     3  2.602284  3.618518
# 1   2019-04-01   Abiemnhom  3.0     3  2.550127  3.682686
# 2   2019-05-01   Abiemnhom  3.0     3  2.658199  3.771679
# 3   2019-06-01   Abiemnhom  3.0     3  2.662421  3.821104
# 4   2019-07-01   Abiemnhom  3.0     3  2.561418  3.929208
# ..         ...         ...  ...   ...       ...       ...
# 457 2019-04-01  Yirol West  3.0     4  3.171358  4.296364
# 458 2019-05-01  Yirol West  3.0     4  2.928294  4.232337
# 459 2019-06-01  Yirol West  4.0     4  2.935937  4.376275
# 460 2019-07-01  Yirol West  3.0     4  2.917080  4.343369
# 461 2019-08-01  Yirol West  3.0     4  2.958410  4.455624
#
# [462 rows x 6 columns]

# %%
fig, ax = plt.subplots(39,2, figsize=(1280/96, 1280/12), dpi=96)
ax = ax.flatten()

for ax_, district in enumerate(all_preds['district'].unique()):
    
    p_ = all_preds.loc[all_preds['district'] == district]
    p_.plot(x='timestamp', y='ipc', ax=ax[ax_], label='IPC')
    p_.plot(x='timestamp', y='pred', ax=ax[ax_], label='Forecast')
    
    ax[ax_].fill_between(p_['timestamp'].values, p_['p10'], p_['p90'], alpha=0.2, color='orange')
    ax[ax_].set_title(district, fontsize=10)
    ax[ax_].legend(fontsize=10)
    ax[ax_].set_xlabel('Date', fontsize=10)
    ax[ax_].set_ylabel('IPC', fontsize=10)
    ax[ax_].tick_params(axis='both', which='major', labelsize=10)
    ax[ax_].tick_params(axis='both', which='minor', labelsize=10)
    ax[ax_].set_ylim(1,5)
    
fig.tight_layout()

# %%
classification_evaluation(all_preds['ipc'], all_preds['pred'])
# Out:
# Accuracy: 0.818
# Precision: 0.867
# Recall: 0.818
# f1-score: 0.836
# Confusion matrix:
#  [[ 12   8   0   0]
#  [  1 335  56   1]
#  [  0  18  31   0]
#  [  0   0   0   0]]

# %% [markdown]
# ## classification of months where ipc went up

# %%
all_preds['prev_ipc'] = all_preds['ipc'].shift(1)

# %%
ipc_increase_preds = all_preds[all_preds['ipc'] > all_preds['prev_ipc']]

# ipc_increase_preds[['prev_ipc', 'ipc','pred']]

# %%
classification_evaluation(ipc_increase_preds.ipc, ipc_increase_preds.pred)
print('relative frequency:', round(ipc_increase_preds.shape[0]/all_preds.shape[0], 2))
# Out:
# Accuracy: 0.641
# Precision: 0.88
# Recall: 0.641
# f1-score: 0.681
# Confusion matrix:
#  [[ 7  0]
#  [14 18]]
# relative frequency: 0.08

# %% [markdown]
# ## classification of months where ipc went down

# %%
all_preds['next_ipc'] = all_preds['ipc'].shift(-1)

# %%
ipc_decrease_preds = all_preds[all_preds['ipc'] > all_preds['next_ipc']]

# ipc_decrease_preds[['next_ipc', 'ipc','pred']]

# %%
classification_evaluation(ipc_decrease_preds.ipc, ipc_decrease_preds.pred)
print('relative frequency:', round(ipc_decrease_preds.shape[0]/all_preds.shape[0], 2))
# Out:
# Accuracy: 0.564
# Precision: 0.779
# Recall: 0.564
# f1-score: 0.613
# Confusion matrix:
#  [[ 5  2]
#  [15 17]]
# relative frequency: 0.08

# %% [markdown]
# ## classification of months where ipc stayed the same

# %%
# all_preds[['prev_ipc', 'ipc', 'next_ipc', 'pred']]

same_ipc = all_preds[all_preds.next_ipc == all_preds.ipc]
# same_ipc[['prev_ipc', 'ipc', 'next_ipc', 'pred']]

# %%
classification_evaluation(same_ipc.ipc, same_ipc.pred)
print('relative frequency:', round(same_ipc.shape[0]/all_preds.shape[0], 2))
# Out:
# Accuracy: 0.864
# Precision: 0.945
# Recall: 0.864
# f1-score: 0.894
# Confusion matrix:
#  [[ 10   3   0]
#  [  1 307  45]
#  [  0   3  14]]
# relative frequency: 0.83

# %% [markdown]
# # DeepAR w/o article topics

# %%
train2 = train[['district', 'ipc', 'ndvi_mean', 'ndvi_anom', 'rain_mean',
       'rain_anom', 'et_mean', 'et_anom', 'count_violence', 'sum_fatalities',
       'food_price_idx', 'area', 'cropland_pct', 'pop', 'ruggedness_mean',
       'pasture_pct', 'timestamp']]

test2 = test[['district', 'ipc', 'ndvi_mean', 'ndvi_anom', 'rain_mean',
       'rain_anom', 'et_mean', 'et_anom', 'count_violence', 'sum_fatalities',
       'food_price_idx', 'area', 'cropland_pct', 'pop', 'ruggedness_mean',
       'pasture_pct', 'timestamp']]

# %%
train_ds2 = PandasDataset.from_long_dataframe(train2, target='ipc', item_id='district', 
                                       timestamp='timestamp', freq='M')

# %%
estimator2 = DeepAREstimator(freq='M', prediction_length=6, num_layers=4, lr=0.002, context_length=12,
                            trainer_kwargs={'max_epochs':8})

predictor2 = estimator2.train(train_ds2, num_workers=4)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\Goshko\anaconda3\envs\dc3\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:71: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
#
#   | Name  | Type        | Params | In sizes | Out sizes
# ---------------------------------------------------------------
# 0 | model | DeepARModel | 49.6 K | ?        | [1, 100, 6]
# ---------------------------------------------------------------
# 49.6 K    Trainable params
# 0         Non-trainable params
# 49.6 K    Total params
# 0.198     Total estimated model params size (MB)
# Epoch 0: : 50it [00:02, 17.10it/s, v_num=65, train_loss=1.080]
# Epoch 0, global step 50: 'train_loss' reached 1.07873 (best 1.07873), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1: : 50it [00:02, 16.87it/s, v_num=65, train_loss=0.574]
# Epoch 1, global step 100: 'train_loss' reached 0.57391 (best 0.57391), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2: : 50it [00:03, 16.15it/s, v_num=65, train_loss=0.617]
# Epoch 2, global step 150: 'train_loss' was not in top 1
# Epoch 3: : 50it [00:03, 15.19it/s, v_num=65, train_loss=0.591]
# Epoch 3, global step 200: 'train_loss' was not in top 1
# Epoch 4: : 50it [00:02, 18.04it/s, v_num=65, train_loss=0.557]
# Epoch 4, global step 250: 'train_loss' reached 0.55726 (best 0.55726), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5: : 50it [00:02, 19.23it/s, v_num=65, train_loss=0.492]
# Epoch 5, global step 300: 'train_loss' reached 0.49202 (best 0.49202), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=5-step=300.ckpt' as top 1
# Epoch 6: : 50it [00:02, 17.25it/s, v_num=65, train_loss=0.420]
# Epoch 6, global step 350: 'train_loss' reached 0.42035 (best 0.42035), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=6-step=350.ckpt' as top 1
# Epoch 7: : 50it [00:02, 17.68it/s, v_num=65, train_loss=0.281]
# Epoch 7, global step 400: 'train_loss' reached 0.28099 (best 0.28099), saving model to 'C:\\Users\\Goshko\\Desktop\\DC3\\JBG060-DC3-23-24-Group24\\lightning_logs\\version_65\\checkpoints\\epoch=7-step=400.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=8` reached.
# Epoch 7: : 50it [00:02, 17.38it/s, v_num=65, train_loss=0.281]

# %%
pred2 = list(predictor2.predict(train_ds2))
all_preds2 = list()

for district in pred2:
    
    district_name = district.item_id
    p = district.samples.mean(axis=0)
    # make 80% confidence interval
    p10 = np.percentile(district.samples, 10, axis=0)
    p90 = np.percentile(district.samples, 90, axis=0)
    dates = pd.date_range(start=district.start_date.to_timestamp(), periods=len(p), freq='M')
    dates2 = []
    
    for month in dates:
        day_num = month.strftime("%d")
        month_reset = month - timedelta(days=int(day_num) - 1)
        dates2.append(month_reset)
    
    district_pred = pd.DataFrame({'timestamp': dates2, 'district': district_name, 'pred': p, 'p10': p10, 'p90': p90})
    all_preds2 += [district_pred]

all_preds2 = pd.concat(all_preds2, ignore_index=True)

all_preds2 = all_preds2.merge(test2, on=['timestamp', 'district'], how='left')
all_preds2['pred'] = all_preds2['pred'].apply(round)

# all_preds2[['timestamp', 'district', 'ipc', 'pred', 'p10', 'p90']]

# %%
classification_evaluation(all_preds2['ipc'], all_preds2['pred'])
# Out:
# Accuracy: 0.784
# Precision: 0.858
# Recall: 0.784
# f1-score: 0.81
# Confusion matrix:
#  [[ 12   8   0]
#  [  2 318  73]
#  [  0  17  32]]

# %%
all_preds2['next_ipc'] = all_preds2['ipc'].shift(-1)
all_preds2['prev_ipc'] = all_preds2['ipc'].shift(1)

# same ipc
same_ipc2 = all_preds2[all_preds2.next_ipc == all_preds2.ipc]
classification_evaluation(same_ipc2.ipc, same_ipc2.pred)
print('relative frequency:', round(same_ipc2.shape[0]/all_preds2.shape[0], 2))
# Out:
# Accuracy: 0.825
# Precision: 0.94
# Recall: 0.825
# f1-score: 0.868
# Confusion matrix:
#  [[ 10   3   0]
#  [  2 292  59]
#  [  0   3  14]]
# relative frequency: 0.83

# %%
# decrease

ipc_decrease_preds2 = all_preds2[all_preds2['ipc'] > all_preds2['next_ipc']]
classification_evaluation(ipc_decrease_preds2.ipc, ipc_decrease_preds2.pred)
print('relative frequency:', round(ipc_decrease_preds2.shape[0]/all_preds2.shape[0], 2))
# Out:
# Accuracy: 0.615
# Precision: 0.831
# Recall: 0.615
# f1-score: 0.659
# Confusion matrix:
#  [[ 6  1]
#  [14 18]]
# relative frequency: 0.08

# %%
# increase

ipc_increase_preds2 = all_preds2[all_preds2['ipc'] > all_preds2['prev_ipc']]
classification_evaluation(ipc_increase_preds2.ipc, ipc_increase_preds2.pred)
print('relative frequency:', round(ipc_increase_preds2.shape[0]/all_preds2.shape[0], 2))
# Out:
# Accuracy: 0.641
# Precision: 0.88
# Recall: 0.641
# f1-score: 0.681
# Confusion matrix:
#  [[ 7  0]
#  [14 18]]
# relative frequency: 0.08
