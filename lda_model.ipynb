# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim import corpora, models
from collections import defaultdict


# Read the data and perform preprocessing

df = pd.read_csv("/Users/abdalrhman/Documents/DC/data/articles_summary_cleaned.csv", parse_dates=["date"]) # Read data into 'df' dataframe

# Data preprocessing
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    return tokens

df['clean_summary'] = df['summary'].apply(preprocess_text)

# Grouping by year and building LDA models
years = df['date'].dt.year.unique()
topic_models = {}

for year in years:
    year_df = df[df['date'].dt.year == year]
    
    # Create a dictionary and a corpus for the year
    dictionary = corpora.Dictionary(year_df['clean_summary'])
    corpus = [dictionary.doc2bow(text) for text in year_df['clean_summary']]
    
    # Train LDA model
    lda_model = models.LdaModel(corpus, num_topics=10, id2word=dictionary, passes=10)
    topic_models[year] = lda_model

# Get the top 10 topics for each year
top_topics_per_year = {}

for year, lda_model in topic_models.items():
    topics = lda_model.print_topics(num_topics=10, num_words=5)
    top_topics_per_year[year] = topics

# Print the top topics for each year
for year, topics in top_topics_per_year.items():
    print(f"Top 10 Topics for {year}:")
    for topic in topics:
        print(topic)
    print("\n")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/abdalrhman/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/abdalrhman/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Top 10 Topics for 2011:
# (0, '0.037*"sudan" + 0.033*"south" + 0.025*"article" + 0.018*"discusses" + 0.017*"state"')
# (1, '0.029*"south" + 0.028*"sudan" + 0.027*"article" + 0.019*"discusses" + 0.011*"government"')
# (2, '0.032*"south" + 0.030*"sudan" + 0.028*"president" + 0.021*"article" + 0.018*"discusses"')
# (3, '0.028*"sudan" + 0.022*"article" + 0.021*"south" + 0.017*"discusses" + 0.008*"republic"')
# (4, '0.025*"sudan" + 0.025*"south" + 0.023*"article" + 0.015*"discusses" + 0.009*"also"')
# (5, '0.061*"sudan" + 0.041*"south" + 0.021*"article" + 0.018*"oil" + 0.016*"discusses"')
# (6, '0.017*"sudan" + 0.013*"south" + 0.011*"article" + 0.009*"discusses" + 0.007*"international"')
# (7, '0.045*"sudan" + 0.036*"south" + 0.016*"article" + 0.016*"rebel" + 0.014*"army"')
# (8, '0.028*"sudan" + 0.025*"article" + 0.025*"south" + 0.018*"discusses" + 0.009*"juba"')
# (9, '0.050*"south" + 0.050*"sudan" + 0.022*"article" + 0.018*"discusses" + 0.010*"development"')
#
#
# Top 10 Topics for 2012:
# (0, '0.026*"sudan" + 0.025*"south" + 0.019*"article" + 0.017*"state" + 0.016*"refugees"')
# (1, '0.066*"sudan" + 0.043*"south" + 0.025*"article" + 0.019*"discusses" + 0.012*"sudanese"')
# (2, '0.037*"state" + 0.027*"jonglei" + 0.019*"article" + 0.016*"discusses" + 0.015*"violence"')
# (3, '0.040*"students" + 0.030*"university" + 0.027*"lra" + 0.025*"education" + 0.017*"uganda"')
# (4, '0.022*"article" + 0.021*"south" + 0.017*"discusses" + 0.017*"sudan" + 0.013*"state"')
# (5, '0.016*"death" + 0.013*"article" + 0.011*"police" + 0.010*"discusses" + 0.009*"penalty"')
# (6, '0.032*"article" + 0.031*"south" + 0.025*"sudan" + 0.021*"discusses" + 0.016*"government"')
# (7, '0.022*"article" + 0.016*"discusses" + 0.016*"sudan" + 0.015*"south" + 0.014*"party"')
# (8, '0.026*"south" + 0.021*"sudan" + 0.019*"article" + 0.016*"discusses" + 0.015*"juba"')
# (9, '0.061*"sudan" + 0.046*"south" + 0.034*"oil" + 0.021*"article" + 0.017*"discusses"')
#
#
# Top 10 Topics for 2013:
# (0, '0.026*"yau" + 0.021*"state" + 0.017*"article" + 0.015*"south" + 0.013*"discusses"')
# (1, '0.033*"article" + 0.031*"sudan" + 0.029*"south" + 0.022*"president" + 0.020*"discusses"')
# (2, '0.024*"south" + 0.018*"article" + 0.016*"sudan" + 0.015*"reconciliation" + 0.012*"peace"')
# (3, '0.044*"sudan" + 0.044*"south" + 0.019*"article" + 0.017*"oil" + 0.016*"discusses"')
# (4, '0.022*"girls" + 0.016*"education" + 0.015*"school" + 0.013*"primary" + 0.009*"schools"')
# (5, '0.033*"south" + 0.031*"sudan" + 0.021*"article" + 0.020*"president" + 0.019*"discusses"')
# (6, '0.026*"south" + 0.023*"sudan" + 0.022*"article" + 0.019*"discusses" + 0.017*"people"')
# (7, '0.029*"sudan" + 0.028*"south" + 0.020*"article" + 0.017*"discusses" + 0.016*"violence"')
# (8, '0.027*"article" + 0.024*"south" + 0.021*"sudan" + 0.018*"discusses" + 0.015*"government"')
# (9, '0.064*"sudan" + 0.039*"south" + 0.021*"article" + 0.020*"abyei" + 0.019*"discusses"')
#
#
# Top 10 Topics for 2014:
# (0, '0.023*"state" + 0.023*"article" + 0.020*"forces" + 0.019*"government" + 0.018*"discusses"')
# (1, '0.027*"south" + 0.023*"people" + 0.022*"sudan" + 0.020*"refugees" + 0.020*"article"')
# (2, '0.067*"un" + 0.054*"mission" + 0.042*"unmiss" + 0.023*"nations" + 0.020*"united"')
# (3, '0.038*"south" + 0.035*"sudan" + 0.027*"article" + 0.020*"discusses" + 0.016*"government"')
# (4, '0.027*"article" + 0.021*"south" + 0.021*"discusses" + 0.019*"state" + 0.016*"sudan"')
# (5, '0.023*"security" + 0.022*"abyei" + 0.018*"bill" + 0.013*"new" + 0.012*"sudan"')
# (6, '0.050*"state" + 0.028*"bahr" + 0.027*"el" + 0.026*"ghazal" + 0.018*"western"')
# (7, '0.044*"south" + 0.038*"sudan" + 0.025*"african" + 0.017*"peace" + 0.016*"discusses"')
# (8, '0.034*"red" + 0.033*"equatoria" + 0.029*"cross" + 0.017*"region" + 0.014*"eastern"')
# (9, '0.030*"south" + 0.030*"sudan" + 0.021*"article" + 0.019*"conflict" + 0.017*"discusses"')
#
#
# Top 10 Topics for 2015:
# (0, '0.016*"article" + 0.013*"discusses" + 0.011*"sudan" + 0.011*"south" + 0.007*"countries"')
# (1, '0.017*"article" + 0.015*"south" + 0.014*"sudan" + 0.014*"discusses" + 0.012*"africa"')
# (2, '0.033*"sudan" + 0.033*"south" + 0.022*"article" + 0.018*"discusses" + 0.011*"conflict"')
# (3, '0.037*"sudan" + 0.030*"south" + 0.019*"article" + 0.016*"discusses" + 0.011*"rights"')
# (4, '0.028*"sudan" + 0.023*"south" + 0.022*"article" + 0.018*"discusses" + 0.007*"juba"')
# (5, '0.030*"south" + 0.028*"sudan" + 0.019*"people" + 0.018*"article" + 0.017*"food"')
# (6, '0.022*"children" + 0.020*"article" + 0.020*"south" + 0.019*"sudan" + 0.017*"discusses"')
# (7, '0.027*"south" + 0.019*"sudan" + 0.018*"article" + 0.015*"discusses" + 0.009*"government"')
# (8, '0.035*"south" + 0.033*"sudan" + 0.029*"peace" + 0.023*"article" + 0.023*"president"')
# (9, '0.024*"south" + 0.018*"article" + 0.015*"discusses" + 0.014*"sudan" + 0.012*"court"')
#
#
# Top 10 Topics for 2016:
# (0, '0.022*"south" + 0.021*"sudan" + 0.019*"people" + 0.017*"article" + 0.015*"food"')
# (1, '0.020*"south" + 0.020*"sudan" + 0.018*"civilians" + 0.018*"article" + 0.018*"un"')
# (2, '0.032*"south" + 0.031*"refugees" + 0.022*"sudan" + 0.016*"article" + 0.016*"discusses"')
# (3, '0.022*"sudan" + 0.016*"south" + 0.015*"article" + 0.012*"human" + 0.011*"discusses"')
# (4, '0.052*"sudan" + 0.035*"south" + 0.022*"article" + 0.017*"discusses" + 0.010*"sudanese"')
# (5, '0.029*"south" + 0.028*"sudan" + 0.023*"article" + 0.016*"discusses" + 0.013*"un"')
# (6, '0.040*"sudan" + 0.040*"south" + 0.025*"article" + 0.023*"president" + 0.019*"discusses"')
# (7, '0.024*"south" + 0.022*"sudan" + 0.021*"article" + 0.016*"discusses" + 0.012*"police"')
# (8, '0.032*"south" + 0.029*"sudan" + 0.022*"government" + 0.020*"article" + 0.019*"president"')
# (9, '0.039*"south" + 0.038*"sudan" + 0.022*"article" + 0.018*"discusses" + 0.010*"eac"')
#
#
# Top 10 Topics for 2017:
# (0, '0.043*"sudan" + 0.042*"south" + 0.019*"article" + 0.017*"discusses" + 0.012*"peace"')
# (1, '0.021*"south" + 0.020*"article" + 0.016*"refugees" + 0.015*"discusses" + 0.013*"sudan"')
# (2, '0.026*"sudan" + 0.023*"south" + 0.020*"article" + 0.016*"discusses" + 0.011*"president"')
# (3, '0.015*"south" + 0.014*"sudan" + 0.011*"four" + 0.010*"article" + 0.010*"discusses"')
# (4, '0.026*"south" + 0.022*"sudan" + 0.022*"article" + 0.019*"refugees" + 0.017*"discusses"')
# (5, '0.032*"south" + 0.027*"sudan" + 0.021*"article" + 0.017*"discusses" + 0.013*"sudanese"')
# (6, '0.015*"south" + 0.014*"sudan" + 0.012*"conflict" + 0.011*"discusses" + 0.011*"article"')
# (7, '0.016*"south" + 0.016*"food" + 0.015*"sudan" + 0.012*"humanitarian" + 0.011*"article"')
# (8, '0.025*"south" + 0.021*"sudan" + 0.016*"article" + 0.015*"discusses" + 0.012*"government"')
# (9, '0.040*"sudan" + 0.024*"south" + 0.018*"article" + 0.017*"discusses" + 0.015*"two"')
#
#
# Top 10 Topics for 2018:
# (0, '0.036*"south" + 0.030*"sudan" + 0.021*"article" + 0.017*"discusses" + 0.012*"peace"')
# (1, '0.015*"south" + 0.014*"peace" + 0.012*"article" + 0.011*"sudan" + 0.010*"discusses"')
# (2, '0.032*"south" + 0.030*"sudan" + 0.016*"article" + 0.014*"discusses" + 0.014*"peace"')
# (3, '0.041*"sudan" + 0.041*"south" + 0.022*"article" + 0.021*"peace" + 0.018*"discusses"')
# (4, '0.015*"article" + 0.015*"south" + 0.013*"sudan" + 0.013*"discusses" + 0.011*"peace"')
# (5, '0.029*"south" + 0.027*"sudan" + 0.021*"article" + 0.016*"discusses" + 0.012*"peace"')
# (6, '0.018*"south" + 0.017*"article" + 0.015*"sudan" + 0.013*"discusses" + 0.008*"conflict"')
# (7, '0.006*"sexual" + 0.006*"violence" + 0.006*"article" + 0.005*"prison" + 0.005*"discusses"')
# (8, '0.018*"south" + 0.016*"sudan" + 0.014*"article" + 0.011*"discusses" + 0.007*"also"')
# (9, '0.014*"article" + 0.011*"south" + 0.011*"discusses" + 0.011*"sudan" + 0.008*"un"')
#
#
# Top 10 Topics for 2019:
# (0, '0.016*"sudan" + 0.014*"south" + 0.012*"article" + 0.010*"discusses" + 0.006*"ongoing"')
# (1, '0.028*"south" + 0.024*"sudan" + 0.019*"peace" + 0.017*"article" + 0.015*"discusses"')
# (2, '0.021*"article" + 0.017*"sudan" + 0.017*"south" + 0.012*"discusses" + 0.010*"violence"')
# (3, '0.012*"children" + 0.011*"health" + 0.010*"families" + 0.009*"idsr" + 0.009*"surveillance"')
# (4, '0.036*"sudan" + 0.032*"south" + 0.021*"article" + 0.018*"peace" + 0.017*"government"')
# (5, '0.040*"sudan" + 0.035*"south" + 0.019*"article" + 0.016*"discusses" + 0.013*"government"')
# (6, '0.017*"article" + 0.013*"south" + 0.013*"discusses" + 0.013*"sudan" + 0.008*"ethiopia"')
# (7, '0.036*"sudan" + 0.032*"south" + 0.020*"article" + 0.016*"discusses" + 0.008*"also"')
# (8, '0.029*"south" + 0.026*"sudan" + 0.017*"article" + 0.015*"discusses" + 0.010*"rights"')
# (9, '0.010*"south" + 0.009*"article" + 0.008*"discusses" + 0.007*"ebola" + 0.007*"sudan"')
#
#
# Top 10 Topics for 2020:
# (0, '0.045*"sudan" + 0.027*"south" + 0.023*"article" + 0.021*"peace" + 0.019*"discusses"')
# (1, '0.020*"south" + 0.018*"sudan" + 0.015*"article" + 0.012*"country" + 0.012*"discusses"')
# (2, '0.030*"south" + 0.028*"sudan" + 0.020*"article" + 0.017*"discusses" + 0.009*"government"')
# (3, '0.031*"sudan" + 0.029*"south" + 0.022*"article" + 0.018*"government" + 0.016*"discusses"')
# (4, '0.020*"south" + 0.019*"sudan" + 0.016*"article" + 0.013*"discusses" + 0.007*"national"')
# (5, '0.020*"south" + 0.019*"sudan" + 0.015*"article" + 0.013*"discusses" + 0.011*"food"')
# (6, '0.033*"sudan" + 0.031*"south" + 0.022*"president" + 0.020*"article" + 0.016*"discusses"')
# (7, '0.019*"south" + 0.017*"article" + 0.014*"discusses" + 0.014*"sudan" + 0.008*"health"')
# (8, '0.016*"article" + 0.010*"discusses" + 0.009*"south" + 0.009*"sudan" + 0.006*"people"')
# (9, '0.023*"sudan" + 0.019*"south" + 0.017*"article" + 0.015*"discusses" + 0.009*"health"')
#
#
# Top 10 Topics for 2021:
# (0, '0.031*"south" + 0.026*"sudan" + 0.018*"article" + 0.015*"discusses" + 0.007*"government"')
# (1, '0.028*"south" + 0.026*"sudan" + 0.019*"article" + 0.015*"discusses" + 0.010*"peace"')
# (2, '0.022*"south" + 0.015*"sudan" + 0.013*"president" + 0.012*"article" + 0.012*"discusses"')
# (3, '0.036*"sudan" + 0.030*"south" + 0.020*"article" + 0.016*"discusses" + 0.012*"peace"')
# (4, '0.017*"sudan" + 0.017*"south" + 0.012*"discusses" + 0.012*"article" + 0.007*"aid"')
# (5, '0.029*"south" + 0.028*"sudan" + 0.018*"article" + 0.015*"discusses" + 0.011*"country"')
# (6, '0.024*"sudan" + 0.022*"south" + 0.020*"article" + 0.018*"health" + 0.014*"discusses"')
# (7, '0.023*"south" + 0.020*"sudan" + 0.015*"article" + 0.013*"peace" + 0.012*"discusses"')
# (8, '0.027*"sudan" + 0.026*"south" + 0.017*"article" + 0.015*"discusses" + 0.009*"people"')
# (9, '0.024*"article" + 0.023*"sudan" + 0.019*"south" + 0.018*"discusses" + 0.012*"people"')
#
#
# Top 10 Topics for 2022:
# (0, '0.020*"south" + 0.018*"sudan" + 0.011*"attacks" + 0.011*"article" + 0.009*"discusses"')
# (1, '0.025*"sudan" + 0.024*"south" + 0.019*"article" + 0.017*"discusses" + 0.010*"national"')
# (2, '0.017*"south" + 0.015*"article" + 0.013*"sudan" + 0.012*"discusses" + 0.008*"africa"')
# (3, '0.022*"sudan" + 0.020*"article" + 0.019*"south" + 0.013*"discusses" + 0.009*"health"')
# (4, '0.031*"south" + 0.027*"sudan" + 0.015*"article" + 0.013*"security" + 0.012*"discusses"')
# (5, '0.018*"sudan" + 0.016*"south" + 0.012*"article" + 0.012*"discusses" + 0.010*"el"')
# (6, '0.028*"south" + 0.027*"sudan" + 0.018*"people" + 0.017*"article" + 0.015*"discusses"')
# (7, '0.016*"south" + 0.016*"sudan" + 0.015*"article" + 0.013*"food" + 0.012*"discusses"')
# (8, '0.025*"sudan" + 0.023*"south" + 0.019*"article" + 0.015*"discusses" + 0.007*"violence"')
# (9, '0.029*"south" + 0.027*"sudan" + 0.019*"article" + 0.015*"discusses" + 0.012*"violence"')
#
#
# Top 10 Topics for 2023:
# (0, '0.020*"article" + 0.017*"south" + 0.016*"sudan" + 0.013*"discusses" + 0.010*"violence"')
# (1, '0.017*"south" + 0.017*"sudan" + 0.012*"country" + 0.009*"article" + 0.008*"discusses"')
# (2, '0.023*"sudan" + 0.015*"article" + 0.013*"discusses" + 0.013*"south" + 0.013*"peace"')
# (3, '0.028*"south" + 0.023*"sudan" + 0.021*"president" + 0.020*"article" + 0.018*"discusses"')
# (4, '0.039*"south" + 0.038*"sudan" + 0.024*"article" + 0.014*"discusses" + 0.012*"winter"')
# (5, '0.025*"sudan" + 0.022*"south" + 0.020*"report" + 0.018*"rights" + 0.017*"human"')
# (6, '0.019*"sudan" + 0.017*"people" + 0.015*"article" + 0.015*"south" + 0.013*"peace"')
# (7, '0.016*"article" + 0.015*"conflict" + 0.010*"discusses" + 0.009*"climate" + 0.009*"food"')
# (8, '0.028*"sudan" + 0.018*"south" + 0.017*"abyei" + 0.014*"article" + 0.011*"discusses"')
# (9, '0.026*"south" + 0.024*"sudan" + 0.015*"article" + 0.012*"discusses" + 0.010*"country"')
