# %% [markdown]
# # Initialization

# %%
from bertopic import BERTopic
import pandas as pd
import os
# Out:
# /Users/xuyou/opt/anaconda3/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/xuyou/opt/anaconda3/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/xuyou/opt/anaconda3/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/xuyou/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
# Read the data and perform preprocessing

df = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"]) # Read data into 'df' dataframe
print(df.shape) # Print dataframe shape

docs = df["summary"].tolist() # Create a list containing all article summaries

df.head() # Show first 5 dataframe entries
# Out:
# (18520, 5)
#                                              summary       date  \
# 0  The article discusses the passing of the new C... 2011-07-07
# 1  The article discusses the military actions tak... 2011-07-03
# 2  The article discusses the signing of a Framewo... 2011-06-30
# 3  The article discusses the upcoming independenc... 2011-07-04
# 4  The article discusses the need for South Sudan... 2011-07-02
#
#     location_article        lat        lng
# 0               Juba   4.859363  31.571250
# 1              Abyei   9.838551  28.486396
# 2  Southern Kordofan  11.036544  30.895824
# 3        South Sudan   6.876992  31.306979
# 4               Juba   4.859363  31.571250

# %%
if os.path.exists('southsudan_model'):
    bertopic = BERTopic.load('southsudan_model')
else:
    bertopic = BERTopic(language="english", calculate_probabilities=True, verbose=True) # Initialize the BERTopic model

    bertopic.fit_transform(docs) # Fit the model to the list of article summaries
    bertopic.save("southsudan_model") # Save the trained model as "southsudan_model"

# %% [markdown]
# # Discovery

# %%
bertopic.get_topic_info()[:10]
# Out:
#    Topic  Count                                        Name  \
# 0     -1   6598                            -1_and_the_in_of
# 1      0    552              0_oil_pipeline_production_fees
# 2      1    350                1_abyei_referendum_area_ngok
# 3      2    280     2_border_zone_agreements_implementation
# 4      3    248         3_cabinet_governor_speaker_assembly
# 5      4    214  4_independence_tribalism_author_challenges
# 6      5    201                    5_igad_talks_addis_ababa
# 7      6    186             6_albashir_omer_president_visit
# 8      7    184       7_million_aid_humanitarian_assistance
# 9      8    178         8_church_churches_bishop_archbishop
#
#                                       Representation  \
# 0  [and, the, in, of, to, south, article, sudan, ...
# 1  [oil, pipeline, production, fees, transit, pet...
# 2  [abyei, referendum, area, ngok, misseriya, reg...
# 3  [border, zone, agreements, implementation, buf...
# 4  [cabinet, governor, speaker, assembly, ministe...
# 5  [independence, tribalism, author, challenges, ...
# 6  [igad, talks, addis, ababa, intergovernmental,...
# 7  [albashir, omer, president, visit, kiir, salva...
# 8  [million, aid, humanitarian, assistance, emerg...
# 9  [church, churches, bishop, archbishop, catholi...
#
#                                  Representative_Docs
# 0  [The article discusses the signing of two agre...
# 1  [The article discusses South Sudan's decision ...
# 2  [The article discusses the failure of Sudan an...
# 3  [The article discusses the resumption of talks...
# 4  [The article discusses the appointment of a ne...
# 5  [The article discusses the history and challen...
# 6  [The article discusses the adjournment of peac...
# 7  [The article discusses the expected visit of S...
# 8  [The article discusses the US President author...
# 9  [The article discusses church leaders in South...
